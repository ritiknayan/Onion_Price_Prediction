# %%
import pandas as pd
import operator as op
import xml.etree.ElementTree as et
import numpy as np
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
sns.set(rc={'figure.figsize':(12.7,8.27)})
import matplotlib.pyplot as plt

# %%
def parse_XML(xml_file, df_cols): 
    """Parse the input XML file and store the result in a pandas 
    DataFrame with the given columns. 
    
    The first element of df_cols is supposed to be the identifier 
    variable, which is an attribute of each node element in the 
    XML data; other features will be parsed from the text content 
    of each sub-element. 
    """
    
    xtree = et.parse(xml_file)
    xroot = xtree.getroot()
    rows = []
    
    for node in xroot: 
        res = []
        res.append(node.attrib.get(df_cols[0]))
        for el in df_cols[1:]: 
            if node is not None and node.find(el) is not None:
                res.append(node.find(el).text)
            else: 
                res.append(None)
        rows.append({df_cols[i]: res[i] 
                     for i, _ in enumerate(df_cols)})
    
    out_df = pd.DataFrame(rows, columns=df_cols)
        
    return out_df

# %%
onion_producing_states=["Maharashtra", "Madhya Pradesh", "Karnataka", "Gujarat", "Rajasthan", "Andhra Pradesh", "Haryana", "West Bengal", "Uttar Pradesh", "Chattisgarh", "Jharkhand","Telangana"]
onion_maturity_days=np.arange(100,176)
onion_non_harv_months=['06','07','08']

# %%
onion_xml=['id','State','District','Market','Commodity','Variety','Arrival_Date','Min_x0020_Price','Max_x0020_Price','Modal_x0020_Price']
data2=parse_XML('Onion_2017.xml',onion_xml)
data=pd.read_csv('Onion_2019.csv')
data2=data2.drop('id',axis=1)

# %%
data.columns=data2.columns

# %%
coldata=[data,data2]
for datas in coldata:
    datas['Month']=datas['Arrival_Date'].str.split('/',expand=True)[1]

    
le=LabelEncoder()
for datas in coldata:
    datas['State_code']=le.fit_transform(datas['State'])
    sc=le.transform(onion_producing_states)
    datas['Price']=datas['Modal_x0020_Price'].apply(pd.to_numeric).div(100)

# %%
for datas in coldata:
    datas['Producing']=0
    datas['Harvesting Month']=1
data.head(10)
# Out:
#                  State                   District       Market Commodity  \
# 0  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 1  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 2  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 3  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 4  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 5  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 6  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 7  Andaman and Nicobar  North and Middle Andaman      Diglipur     Onion
# 8  Andaman and Nicobar              South Andaman   Port Blair     Onion
# 9  Andaman and Nicobar              South Andaman   Port Blair     Onion
#
#   Variety Arrival_Date  Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price  \
# 0   Other   07/06/2019             6000            10000             8000.0
# 1   Other   11/06/2019             6000            10000             8000.0
# 2   Other   12/06/2019             6000            10000             8000.0
# 3   Other   13/06/2019             6000            10000             8000.0
# 4   Other   14/06/2019             4000             8000             6000.0
# 5   Other   15/06/2019             6000            10000             8000.0
# 6   Other   17/06/2019             4000             8000             6000.0
# 7   Other   02/03/2019             3000             4000             3500.0
# 8   Other   04/03/2019             2000             3500             3000.0
# 9   Other   07/03/2019             2500             3500             3000.0
#
#   Month  State_code  Price  Producing  Harvesting Month
# 0    06           0   80.0          0                 1
# 1    06           0   80.0          0                 1
# 2    06           0   80.0          0                 1
# 3    06           0   80.0          0                 1
# 4    06           0   60.0          0                 1
# 5    06           0   80.0          0                 1
# 6    06           0   60.0          0                 1
# 7    03           0   35.0          0                 1
# 8    03           0   30.0          0                 1
# 9    03           0   30.0          0                 1

# %%
x=data.values

for i in range(len(x)):
    for j in range(len(sc)):
        if x[i,10]==sc[j]:
            x[i,12]=1
for i in range(len(x)):
    for j in range(len(onion_non_harv_months)):
        if x[i,9]==onion_non_harv_months[j]:
            x[i,13]=0

dataset=pd.DataFrame(x,columns=data.columns)

# %%
x=data2.values

for i in range(len(x)):
    for j in range(len(sc)):
        if x[i,10]==sc[j]:
            x[i,12]=1
for i in range(len(x)):
    for j in range(len(onion_non_harv_months)):
        if x[i,9]==onion_non_harv_months[j]:
            x[i,13]=0

datasets=pd.DataFrame(x,columns=data.columns)

# %%
dataset.head(10)
# Out:
#                  State                   District       Market Commodity  \
# 0  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 1  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 2  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 3  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 4  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 5  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 6  Andaman and Nicobar                    Nicobar  Car Nicobar     Onion
# 7  Andaman and Nicobar  North and Middle Andaman      Diglipur     Onion
# 8  Andaman and Nicobar              South Andaman   Port Blair     Onion
# 9  Andaman and Nicobar              South Andaman   Port Blair     Onion
#
#   Variety Arrival_Date Min_x0020_Price Max_x0020_Price Modal_x0020_Price  \
# 0   Other   07/06/2019            6000           10000              8000
# 1   Other   11/06/2019            6000           10000              8000
# 2   Other   12/06/2019            6000           10000              8000
# 3   Other   13/06/2019            6000           10000              8000
# 4   Other   14/06/2019            4000            8000              6000
# 5   Other   15/06/2019            6000           10000              8000
# 6   Other   17/06/2019            4000            8000              6000
# 7   Other   02/03/2019            3000            4000              3500
# 8   Other   04/03/2019            2000            3500              3000
# 9   Other   07/03/2019            2500            3500              3000
#
#   Month State_code Price Producing Harvesting Month
# 0    06          0    80         0                0
# 1    06          0    80         0                0
# 2    06          0    80         0                0
# 3    06          0    80         0                0
# 4    06          0    60         0                0
# 5    06          0    80         0                0
# 6    06          0    60         0                0
# 7    03          0    35         0                1
# 8    03          0    30         0                1
# 9    03          0    30         0                1

# %%
sns.boxplot(x='State_code',y='Price',data=data)

# %%
sns.catplot(x='Month',y='Price',col='State',col_wrap=2,data=dataset,kind='box')

# %%
g = sns.FacetGrid(dataset,  col="State",hue="Harvesting Month" ,col_wrap=4, height=2.5)
g.map(plt.scatter,"Month","Price")

# %%
g = sns.FacetGrid(datasets,  col="State",hue="Harvesting Month", col_wrap=4, height=2.5)
g.map(plt.scatter,"Month","Price")

# %%
pal=dict()
g = sns.FacetGrid(dataset,  col="Month",hue="Producing", col_wrap=2, height=4)
g.map(plt.scatter,"State_code","Price")

# %%
g = sns.FacetGrid(datasets,  col="Month",hue="Producing", col_wrap=3, height=4)
g.map(plt.scatter,"State_code","Price")
